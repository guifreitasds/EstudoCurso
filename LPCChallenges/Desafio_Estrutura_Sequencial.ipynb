# %%
# QUESTÃO 1

print('Alô ETE PORTO DIGITAL')
# Out:
# Alô ETE PORTO DIGITAL

# %%
# QUESTÃO 2

number = int(input('Insira um número: '))

print ('O número informado foi ' +  str(number))

# %%
# QUESTÃO 3

number1 = int(input('Insira um número: '))
number2 = int(input('Insira um número: '))
soma = number1 + number2
print('A soma dos números é: ' + str(soma))

# %%
# QUESTÃO 4

grade1 = float(input('Insira a primeira nota: '))
grade2 = float(input('Insira a segunda nota: '))
grade3 = float(input('Insira a terceira nota: '))
grade4= float(input('Insira a quarta nota: '))

average = ((grade1 + grade2 + grade3 + grade4) /4)

print('A média anual foi: ' + str(average))

# %%
# QUESTÃO 5

meter = float(input('Insira a medida em metros: '))

centimeter = meter * 100

print('A medida em centímetros é de: ' + str(centimeter) + 'cm')

# %%
# QUESTÃO 6

rayo = float(input('Insira o raio do círculo: '))

area = 3.14 * (rayo * rayo)

print('A área do círculo é: ' + str(area))
# Out:
# Insira o raio do círculo: 5
# A área do círculo é: 78.5

# %%
# QUESTÃO 7

square = float(input('Insira o lado do quadrado: '))

area = square * square

doublearea = area * 2

print('O dobro da área do quadrado é: ' + str(doublearea))

# %%
# QUESTÃO 8

ghour = float(input('Insira seu ganho por hora: '))
mhour = int(input('Insira suas horas trabalhadas no mês: '))

total = ghour * mhour

print('Seu ganho total do mês foi de: R$' + str(total))
# Out:
# Insira seu ganho por hora: 20
# Insira suas horas trabalhadas no mês: 160
# Seu ganho total do mês foi de: R$3200.0

# %%
# QUESTÃO 9

f = float(input('Insira a temperatura em fahrenheit: '))

celsius = (f - 32) / 1.8

print('A temperatura em celsius é: ' + str(celsius))
# Out:
# Insira a temperatura em fahrenheit: 88.7
# A temperatura em celsius é: 31.5

# %%
# QUESTÃO 10

c = float(input('Insira a temperatura em celsius: '))

fahrenheit = (c * 1.8) + 32

print('A temperatura em fahrenheit é: ' + str(fahrenheit))
# Out:
# Insira a temperatura em celsius: 31.5
# A temperatura em fahrenheit é: 88.7

# %%
# QUESTÃO 11

n1 = int(input('Insira um número inteiro: '))
n2 = int(input('Insira um número inteiro: '))

r1 = float(input('Insira um número real: '))

first = 2 * n1 * n2 / 2
print('O produto do dobro do primeiro com a metade do segundo é: ' + str(first))

second = 3 * n1 + r1
print('A soma do triplo do primeiro com o terceiro é: ' + str(second))

third = r1 * r1 * r1

print('O terceiro elevado ao cubo é: ' + str(third))
# Out:
# Insira um número inteiro: 2
# Insira um número inteiro: 3
# Insira um número real: 4.5
# O produto do dobro do primeiro com a metade do segundo é: 6.0
# A soma do triplo do primeiro com o terceiro é: 10.5
# O terceiro elevado ao cubo é: 91.125

# %%
# QUESTÃO 12

height = float(input('Insira sua altura em metros: '))

idealweight = (72.7 * height) - 58

print('Seu peso ideal é de: ' + str(idealweight) + 'Kg')
# Out:
# Insira sua altura em metros: 1.75
# Seu peso ideal é de: 69.22500000000001Kg

# %%
# QUESTÃO 13

h = float(input('Insira sua altura em metros: '))

idealweight = (72.7 * h) - 58
idealweight1 = (62.1 * h) - 44.7

print('Seu peso ideal, caso você for homem, é de: ' + str(idealweight) + 'Kg')
print('Seu peso ideal, caso você for mulher, é de: ' + str(idealweight1) + 'Kg')
# Out:
# Insira sua altura em metros: 1.75
# Seu peso ideal, caso você for homem, é de: 69.22500000000001Kg
# Seu peso ideal, caso você for mulher, é de: 63.974999999999994Kg

# %%
# QUESTÃO 14

fishw = float(input('Insira o peso dos peixes: '))

excess = fishw - 50

ticket = excess * 4

print('A multa a ser paga é de: R$' + str(ticket))
# Out:
# Insira o peso dos peixes: 51
# A multa a ser paga é de: R$4.0

# %%
# QUESTÃO 15

size = float(input('Qual o tamanho do arquivo a ser baixado em MB: '))

meter = float(input('Qual a velocidade da internet em Mbps: '))

totaltime = size / (meter * 60)

print('O tempo total de download será ' + str(totaltime) + ' minutos')
# Out:
# Qual o tamanho do arquivo a ser baixado em MB: 10000
# Qual a velocidade da internet em Mbps: 5
# O tempo total de download será 33.333333333333336 minutos
